# %% [markdown]
# # 1.Lý do chọn đề tài

# %% [markdown]
# # 2. Loading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart_disease_final.csv")

# %%
df.head()
# Out:
#    thalach  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    168.0        1                     34.92         0                 20
# 1    155.0        1                     10.57         0                 38
# 2    125.0        1                      8.76         0                 20
# 3    161.0        1                      6.66         0                 20
# 4    106.0        1                      9.60         1                 20
#
#    high_blood_pressure  platelets  sex  smoking  serum_creatinin  \
# 0                    1     265.00    1        0              5.4
# 1                    1     263.36    1        0              3.9
# 2                    1     162.00    1        1              5.5
# 3                    1     210.00    1        0              2.6
# 4                    1     327.00    0        0              5.6
#
#    cholestor( mg/dl)  DEATH_EVENT
# 0                212            1
# 1                203            1
# 2                204            1
# 3                203            1
# 4                294            1

# %%
df.shape
# Out:
# (299, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   thalach                   299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    float64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   sex                       299 non-null    int64
#  8   smoking                   299 non-null    int64
#  9   serum_creatinin           299 non-null    float64
#  10  cholestor( mg/dl)         299 non-null    int64
#  11  DEATH_EVENT               299 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 28.2 KB

# %%
df.describe().T
# Out:
#                           count        mean        std     min     25%  \
# thalach                   299.0  150.573411  23.007743   71.00  138.00
# anaemia                   299.0    0.441472   0.497395    0.00    0.00
# creatinine_phosphokinase  299.0   27.306856  32.074795    1.38    6.99
# diabetes                  299.0    0.421405   0.494612    0.00    0.00
# ejection_fraction         299.0   36.969900  11.531505   12.00   30.00
# high_blood_pressure       299.0    0.411371   0.492907    0.00    0.00
# platelets                 299.0  263.358194  97.804237   25.10  212.50
# sex                       299.0    0.648829   0.478136    0.00    0.00
# smoking                   299.0    0.321070   0.467670    0.00    0.00
# serum_creatinin           299.0    4.858194   2.617819    1.00    2.50
# cholestor( mg/dl)         299.0  246.093645  57.012579  126.00  207.50
# DEATH_EVENT               299.0    0.461538   0.499354    0.00    0.00
#
#                              50%     75%     max
# thalach                   153.00  168.00  195.00
# anaemia                     0.00    1.00    1.00
# creatinine_phosphokinase   13.98   34.92  167.64
# diabetes                    0.00    1.00    1.00
# ejection_fraction          35.00   40.00   80.00
# high_blood_pressure         0.00    1.00    1.00
# platelets                 262.00  303.50  850.00
# sex                         1.00    1.00    1.00
# smoking                     0.00    1.00    1.00
# serum_creatinin             4.40    6.90   10.00
# cholestor( mg/dl)         239.00  283.00  564.00
# DEATH_EVENT                 0.00    1.00    1.00

# %% [markdown]
#   ## <font color = brown>Dataset Description</font>
#  Feature | Explanation | Measurement	| Range
# ------------- | ------------- |------------- | -------------
# Thalach	|nhịp tim tối đa đạt được	|nhịp/phút |	[71,..., 195]
# Anaemia	|Decrease of red <br> blood cells or hemoglobin |	Boolean|	0, 1
# Creatinine phosphokinase<br>(CPK) |	Level of the CPK enzyme <br>in the blood |	U/L|	[1.38,..., 167.64]
# Diabetes|	If the patient has diabetes |	Boolean	| 0, 1
# Ejection fraction|	Percentage of blood leaving<br>the heart at each contraction|Percentage	|	[12,..., 80]
# Sex	| Woman or man |	Binary|	0, 1
# Platelets|	Platelets in the blood|	platelets/mL|	[25.1,..., 850.00]
# High blood pressure| If the patient has hypertension| Boolean |0,1
# cholestor| Serum cholestoral | mg/dl | [126,...,564]
# Smoking|	If the patient smokes|	Boolean	|0, 1
# Serum_creatinin|	Level of serum creatinine in the blood|	 mg/dl |	[1,...,10]
# DEATH EVENT<br>(TARGET)|	If the patient died during the follow-up period|	Boolean|	0, 1

# %% [markdown]
# # 3. Explore Data Analysis (EDA): Phân tích và trực quan hóa dữ liệu

# %%
df["DEATH_EVENT"].value_counts()
# Out:
# DEATH_EVENT
# 0    161
# 1    138
# Name: count, dtype: int64

# %%
# df["DEATH_EVENT"].value_counts(normalize = True) # theo %

# %% [markdown]
# ### 1. Phân tích đơn biến

# %% [markdown]
# #### 1.1 Các biến phân loại
# * anaemia
# * diabetes
# * high_blood_pressure
# * sex
# * smoking
# * DEATH_EVENT

# %%
categorical_list = ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking', 'DEATH_EVENT']

# %%
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5,n_rows*5))

for r in range(0, n_rows):
    for c in range(0, n_cols):
        i = r*n_cols + c # index list cols
        if(i < len(categorical_list)):
            ax_i = ax[r,c]
            sns.countplot(data=df, x=categorical_list[i], palette='Blues', ax=ax_i, legend = False)
            ax_i.set_title(f"{categorical_list[i]}")
            total_height = sum([p.get_height() for p in ax_i.patches]) # Tổng chiều cao của tất cả các cột
            for rect in ax_i.patches:
                height = rect.get_height() / total_height * 100 # Tính phần trăm chiều cao của cột
                ax_i.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 11) # hiển thị theo số lượng
                ax_i.text(rect.get_x() + rect.get_width()/2., height + 2, f'{height:.2f}%', ha='center', va='bottom', fontsize=11) # Hiển thị phần trăm 
plt.tight_layout() # ko chồng đồ thị
# Out:
# C:\Users\huyho\AppData\Local\Temp\ipykernel_23012\2933292818.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=categorical_list[i], palette='Blues', ax=ax_i, legend = False)
# C:\Users\huyho\AppData\Local\Temp\ipykernel_23012\2933292818.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=categorical_list[i], palette='Blues', ax=ax_i, legend = False)
# C:\Users\huyho\AppData\Local\Temp\ipykernel_23012\2933292818.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=categorical_list[i], palette='Blues', ax=ax_i, legend = False)
# C:\Users\huyho\AppData\Local\Temp\ipykernel_23012\2933292818.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=categorical_list[i], palette='Blues', ax=ax_i, legend = False)
# C:\Users\huyho\AppData\Local\Temp\ipykernel_23012\2933292818.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=categorical_list[i], palette='Blues', ax=ax_i, legend = False)
# C:\Users\huyho\AppData\Local\Temp\ipykernel_23012\2933292818.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=categorical_list[i], palette='Blues', ax=ax_i, legend = False)

# %% [markdown]
# #### <font color = brown>Data Insight 1:</font>
#
# **`1. ~55,85% dân số được nghiên cứu có triệu chứng thiếu máu trong khi ~44,15% không bị thiếu máu.`**
#
# **`2. ~57,86% dân số mắc bệnh tiểu đường trong khi ~42,14% không mắc bệnh tiểu đường.`**
#
# **`3. ~58,86% dân số bị huyết áp cao hoặc huyết áp cao trong khi ~41,14% có huyết áp bình thường.`**
#
# **`4. ~64,88% dân số là nam giới trong khi ~35,12% là nữ.`**
#
# **`5. ~67,89% dân số có thói quen hút thuốc trong khi ~32,11% là người không hút thuốc.`**
#
# **`6. ~53,85% dân số còn sống trong khi 46,15% đã chết.`**

# %% [markdown]
# ### 1.2. Các biến số
# * thalach
# * creatinine_phosphokinase
# * ejection_fraction
# * platelets
# * serum_creatinin
# * cholestor

# %%
numerical_list = ['thalach', 'creatinine_phosphokinase', 'ejection_fraction', 'platelets', 'serum_creatinin', 'cholestor( mg/dl)']

# %%
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*4,n_rows*4))

for r in range(0, n_rows):
    for c in range(0, n_cols):
        i = r*n_cols + c # index list cols
        if(i < len(numerical_list)):
            ax_i = ax[r,c]
            sns.histplot(data=df, x=numerical_list[i], ax=ax_i)
            ax_i.set_title(f"{numerical_list[i]}")
plt.tight_layout() # ko chồng đồ thị

# %%
# đánh giá

# %% [markdown]
# ### 2. Phân tích 2 biến

# %%
cols = ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking']
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5,n_rows*5))

for r in range(0, n_rows):
    for c in range(0, n_cols):
        i = r*n_cols + c # index list cols
        if(i < len(cols)):
            ax_i = ax[r,c]
            sns.countplot(data=df, x=cols[i], hue = 'DEATH_EVENT', ax=ax_i)
            # total_height = len(df) 
            for rect in ax_i.patches:
                height = rect.get_height() / total_height * 100 # Tính phần trăm chiều cao của cột
                if height != 0: # chỉ hiển thị nếu chiều cao khác 0
                    ax_i.text(rect.get_x() + rect.get_width() / 2, rect.get_height() + 2, rect.get_height(), horizontalalignment='center', fontsize = 11) # hiển thị theo số lượng
                    ax_i.text(rect.get_x() + rect.get_width()/2., height + 2, f'{height:.2f}%', ha='center', va='bottom', fontsize=11) # Hiển thị phần trăm 
            ax_i.set_title(f"DEATH_EVENT vs {cols[i]}")
            ax_i.legend(title='DEATH_EVENT', labels = ['0', '1'])
ax.flat[-1].set_visible(False) # bỏ hình cuối
plt.tight_layout() # ko chồng đồ thị

# %%
# đánh giá theo từng biểu đồ

# %%
cols = ['thalach', 'creatinine_phosphokinase', 'ejection_fraction', 'platelets', 'serum_creatinin', 'cholestor( mg/dl)']
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*4,n_rows*4))
for r in range(0, n_rows):
    for c in range(0, n_cols):
        i = r*n_cols + c # index list cols
        if(i < len(cols)):
            ax_i = ax[r,c]
            sns.histplot(data=df, x=cols[i], hue = 'DEATH_EVENT', kde = True, ax=ax_i)
            ax_i.set_title(f"DEATH_EVENT vs {cols[i]}")
            ax_i.legend(title='', loc='upper right', labels = ['NOT DEATH', 'DEATH'])
plt.tight_layout() # ko chồng đồ thị

# %% [markdown]
# # nhận xét

# %% [markdown]
# ### Ma trận tương quan giữa các dữ liệu

# %%
df.corr()
# Out:
#                            thalach   anaemia  creatinine_phosphokinase  \
# thalach                   1.000000  0.002187                 -0.079513
# anaemia                   0.002187  1.000000                 -0.144817
# creatinine_phosphokinase -0.079513 -0.144817                  1.000000
# diabetes                  0.006207 -0.035811                  0.057300
# ejection_fraction         0.048116  0.018706                 -0.012999
# high_blood_pressure      -0.025767  0.023255                 -0.046898
# platelets                -0.130618 -0.050552                 -0.003176
# sex                       0.004548 -0.079658                  0.019861
# smoking                  -0.086090 -0.106481                 -0.085894
# serum_creatinin           0.066179  0.072981                  0.024446
# cholestor( mg/dl)        -0.055472  0.017826                  0.063860
# DEATH_EVENT              -0.043178  0.055082                  0.012021
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# thalach                   0.006207           0.048116            -0.025767
# anaemia                  -0.035811           0.018706             0.023255
# creatinine_phosphokinase  0.057300          -0.012999            -0.046898
# diabetes                  1.000000          -0.072489            -0.011463
# ejection_fraction        -0.072489           1.000000            -0.017887
# high_blood_pressure      -0.011463          -0.017887             1.000000
# platelets                 0.092552           0.018113             0.125775
# sex                      -0.166762          -0.076175            -0.153862
# smoking                  -0.151669           0.006776            -0.079943
# serum_creatinin           0.019872          -0.095308             0.064085
# cholestor( mg/dl)         0.057263          -0.082357             0.036239
# DEATH_EVENT               0.079429          -0.341990             0.275818
#
#                           platelets       sex   smoking  serum_creatinin  \
# thalach                   -0.130618  0.004548 -0.086090         0.066179
# anaemia                   -0.050552 -0.079658 -0.106481         0.072981
# creatinine_phosphokinase  -0.003176  0.019861 -0.085894         0.024446
# diabetes                   0.092552 -0.166762 -0.151669         0.019872
# ejection_fraction          0.018113 -0.076175  0.006776        -0.095308
# high_blood_pressure        0.125775 -0.153862 -0.079943         0.064085
# platelets                  1.000000 -0.125121  0.028235        -0.022039
# sex                       -0.125121  1.000000  0.445892         0.082334
# smoking                    0.028235  0.445892  1.000000        -0.051494
# serum_creatinin           -0.022039  0.082334 -0.051494         1.000000
# cholestor( mg/dl)         -0.047778  0.038633  0.031969         0.098358
# DEATH_EVENT                0.026333  0.006487 -0.047529         0.243535
#
#                           cholestor( mg/dl)  DEATH_EVENT
# thalach                           -0.055472    -0.043178
# anaemia                            0.017826     0.055082
# creatinine_phosphokinase           0.063860     0.012021
# diabetes                           0.057263     0.079429
# ejection_fraction                 -0.082357    -0.341990
# high_blood_pressure                0.036239     0.275818
# platelets                         -0.047778     0.026333
# sex                                0.038633     0.006487
# smoking                            0.031969    -0.047529
# serum_creatinin                    0.098358     0.243535
# cholestor( mg/dl)                  1.000000     0.338179
# DEATH_EVENT                        0.338179     1.000000

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(data=df.corr(), annot=True, fmt=".2f");

# %% [markdown]
# # 4. Tiền xử lý dữ liệu

# %%
# cân bằng
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority')
X = df.drop('DEATH_EVENT', axis=1)
y = df['DEATH_EVENT']
X_sm, y_sm = smote.fit_resample(X, y)
df_n = pd.DataFrame(X_sm, columns=X.columns)
df_n['DEATH_EVENT'] = y_sm

# %%
sns.countplot(data=df, x='DEATH_EVENT');

# %%
sns.countplot(data=df_n, x='DEATH_EVENT');

# %%
# scale
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
# fit và transform đồng thời
normalized = scaler.fit_transform(df_n)
df_sc = pd.DataFrame(normalized, columns=df_n.columns)
df_sc
# Out:
#       thalach  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.782258      1.0                  0.201732       0.0           0.117647
# 1    0.677419      1.0                  0.055275       0.0           0.382353
# 2    0.435484      1.0                  0.044388       0.0           0.117647
# 3    0.725806      1.0                  0.031757       0.0           0.117647
# 4    0.282258      1.0                  0.049441       1.0           0.117647
# ..        ...      ...                       ...       ...                ...
# 317  0.421304      1.0                  0.029881       0.0           0.264706
# 318  0.657968      0.0                  0.036788       1.0           0.441176
# 319  0.665993      0.0                  0.170842       0.0           0.338235
# 320  0.440133      0.0                  0.030796       0.0           0.264706
# 321  0.798387      0.0                  0.081253       0.0           0.264706
#
#      high_blood_pressure  platelets  sex  smoking  serum_creatinin  \
# 0                    1.0   0.290823  1.0      0.0         0.488889
# 1                    1.0   0.288835  1.0      0.0         0.322222
# 2                    1.0   0.165960  1.0      1.0         0.500000
# 3                    1.0   0.224148  1.0      0.0         0.177778
# 4                    1.0   0.365984  0.0      0.0         0.511111
# ..                   ...        ...  ...      ...              ...
# 317                  0.0   0.441029  1.0      0.0         0.254976
# 318                  1.0   0.302808  1.0      0.0         0.507795
# 319                  1.0   0.288835  0.0      0.0         0.231877
# 320                  0.0   0.439353  1.0      0.0         0.222549
# 321                  0.0   0.307940  1.0      0.0         0.654933
#
#      cholestor( mg/dl)  DEATH_EVENT
# 0             0.196347          1.0
# 1             0.175799          1.0
# 2             0.178082          1.0
# 3             0.175799          1.0
# 4             0.383562          1.0
# ..                 ...          ...
# 317           0.369863          1.0
# 318           0.442922          1.0
# 319           0.253425          1.0
# 320           0.378995          1.0
# 321           0.399543          1.0
#
# [322 rows x 12 columns]

# %%
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# # fit và transform đồng thời
# normalized = scaler.fit_transform(df_n)
# df_sc = pd.DataFrame(normalized, columns=df_n.columns)
# df_sc

# %%
# feature selection

# %%
label = df_sc['DEATH_EVENT']
values = df_sc[['thalach','anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 'high_blood_pressure', 'platelets', 'sex', 'smoking', 'serum_creatinin', 'cholestor( mg/dl)']]

from sklearn.feature_selection import SelectKBest, chi2
bestfeatures = SelectKBest(score_func=chi2, k='all')
fit = bestfeatures.fit(values, label)
dfscores = np.array(fit.scores_) 
dfcolumns = np.array(values.columns)

featureScores = pd.DataFrame({"Feature": dfcolumns, "Scores": dfscores})
featureScores['Scores'] = featureScores['Scores'].apply(lambda x : round(x,2))
featureScores = featureScores.sort_values(['Scores'], ascending=False)
featureScores
# Out:
#                      Feature  Scores
# 5        high_blood_pressure   11.11
# 9            serum_creatinin    3.14
# 10         cholestor( mg/dl)    2.81
# 4          ejection_fraction    2.59
# 8                    smoking    2.04
# 3                   diabetes    0.48
# 1                    anaemia    0.35
# 7                        sex    0.08
# 0                    thalach    0.04
# 6                  platelets    0.01
# 2   creatinine_phosphokinase    0.00

# %%
plt.figure(figsize=(10, 6))
plt.barh(featureScores['Feature'], featureScores['Scores'], color='skyblue')
plt.xlabel('Scores')
plt.title('Scores for Different Features')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
# chọn 4 feature: ejection_fraction, cholestor( mg/dl), time, high_blood_pressure

# %%
df_sc
# Out:
#       thalach  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.782258      1.0                  0.201732       0.0           0.117647
# 1    0.677419      1.0                  0.055275       0.0           0.382353
# 2    0.435484      1.0                  0.044388       0.0           0.117647
# 3    0.725806      1.0                  0.031757       0.0           0.117647
# 4    0.282258      1.0                  0.049441       1.0           0.117647
# ..        ...      ...                       ...       ...                ...
# 317  0.421304      1.0                  0.029881       0.0           0.264706
# 318  0.657968      0.0                  0.036788       1.0           0.441176
# 319  0.665993      0.0                  0.170842       0.0           0.338235
# 320  0.440133      0.0                  0.030796       0.0           0.264706
# 321  0.798387      0.0                  0.081253       0.0           0.264706
#
#      high_blood_pressure  platelets  sex  smoking  serum_creatinin  \
# 0                    1.0   0.290823  1.0      0.0         0.488889
# 1                    1.0   0.288835  1.0      0.0         0.322222
# 2                    1.0   0.165960  1.0      1.0         0.500000
# 3                    1.0   0.224148  1.0      0.0         0.177778
# 4                    1.0   0.365984  0.0      0.0         0.511111
# ..                   ...        ...  ...      ...              ...
# 317                  0.0   0.441029  1.0      0.0         0.254976
# 318                  1.0   0.302808  1.0      0.0         0.507795
# 319                  1.0   0.288835  0.0      0.0         0.231877
# 320                  0.0   0.439353  1.0      0.0         0.222549
# 321                  0.0   0.307940  1.0      0.0         0.654933
#
#      cholestor( mg/dl)  DEATH_EVENT
# 0             0.196347          1.0
# 1             0.175799          1.0
# 2             0.178082          1.0
# 3             0.175799          1.0
# 4             0.383562          1.0
# ..                 ...          ...
# 317           0.369863          1.0
# 318           0.442922          1.0
# 319           0.253425          1.0
# 320           0.378995          1.0
# 321           0.399543          1.0
#
# [322 rows x 12 columns]

# %%
feature = ['ejection_fraction', 'cholestor( mg/dl)', 'serum_creatinin', 'high_blood_pressure']

# %%
X = df_sc[feature]
y = df_sc['DEATH_EVENT']

# %%
X.head()
# Out:
#    ejection_fraction  cholestor( mg/dl)  serum_creatinin  high_blood_pressure
# 0           0.117647           0.196347         0.488889                  1.0
# 1           0.382353           0.175799         0.322222                  1.0
# 2           0.117647           0.178082         0.500000                  1.0
# 3           0.117647           0.175799         0.177778                  1.0
# 4           0.117647           0.383562         0.511111                  1.0

# %%
y.head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: DEATH_EVENT, dtype: float64

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình

# %%
# Một số thuật toán machine learning như Decision Trees, Random Forests không nhất thiết cần phải scale dữ liệu 
# trước khi huấn luyện vì chúng không phụ thuộc vào tỷ lệ của các biến. 
# Tuy nhiên, các thuật toán như SVM, KNN, Neural Networks thì thường cần scale dữ liệu để đảm bảo rằng các biến có cùng tỷ lệ và đồng nhất.

# %%
from sklearn.model_selection import train_test_split
# chia thành 2 tập train và test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

# %%
# Áp dụng Logistic Regression
# from sklearn.linear_model import LogisticRegression 
# from sklearn.metrics import precision_score, recall_score, classification_report, confusion_matrix, accuracy_score

# %%
# log_reg = LogisticRegression()
# log_reg.fit(X_train, y_train)

# %%
# log_reg.score(X_test, y_test) #Accuracy score

# %%
# y_pred = log_reg.predict(X_test)

# %%
# precision_score(y_test, y_pred), recall_score(y_test, y_pred), accuracy_score(y_test, y_pred)

# %%
# print(classification_report(y_test, y_pred))

# %%
# from sklearn import metrics
# confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
# cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

# cm_display.plot()
# plt.show()

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

from sklearn import metrics

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
def model(classifier,X_train,y_train,X_test,y_test):
    # train mô hình
    classifier.fit(X_train,y_train)
    # Đánh giá mô hình
    y_pred = classifier.predict(X_test)
    print(classification_report(y_test, y_pred))
    # trực quan hóa ma trận nhầm lẫn
    plot_confusion_matrix(y_test, y_pred)
    # trực quan hóa ROC-Curve điểm AUC
    plot_roc_curve(y_test, y_pred)
    print(f'AUC score: {roc_auc_score(y_test, y_pred)}')
    plt.show

# %%
def plot_roc_curve(y_test, y_pred):
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    plt.style.use('seaborn-v0_8-whitegrid')
    plt.plot(fpr, tpr)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

# %%
def plot_confusion_matrix(y_test, y_pred):
    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
    cm_display.plot()
    plt.grid(False)
    plt.show()

# %%
model(LogisticRegression(),X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.84      0.72        31
#          1.0       0.79      0.56      0.66        34
#
#     accuracy                           0.69        65
#    macro avg       0.71      0.70      0.69        65
# weighted avg       0.72      0.69      0.69        65
# AUC score: 0.6987666034155597

# %%
model(DecisionTreeClassifier(random_state=0),X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.68      0.69        31
#          1.0       0.71      0.74      0.72        34
#
#     accuracy                           0.71        65
#    macro avg       0.71      0.71      0.71        65
# weighted avg       0.71      0.71      0.71        65
# AUC score: 0.7063567362428844

# %%
model(RandomForestClassifier(), X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.84      0.75        31
#          1.0       0.81      0.65      0.72        34
#
#     accuracy                           0.74        65
#    macro avg       0.75      0.74      0.74        65
# weighted avg       0.75      0.74      0.74        65
# AUC score: 0.7428842504743833

# %%
model(SVC(kernel = 'linear', probability = True), X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.87      0.75        31
#          1.0       0.83      0.59      0.69        34
#
#     accuracy                           0.72        65
#    macro avg       0.75      0.73      0.72        65
# weighted avg       0.75      0.72      0.72        65
# AUC score: 0.7296015180265656
